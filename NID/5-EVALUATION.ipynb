# %%
import numpy as np
import pandas as pd
import altair as alt
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from scipy.stats import chi2_contingency
from collections import Counter
from imblearn.over_sampling import SMOTE

# %%
def model_result_df():
    frames=[]
    _result = pd.DataFrame(SINGLE_MODELS_RESULTS)
    _columns=_result.columns.values
    for i in enumerate(_columns):
        name = i[1]
        _RESULTS=TEST_MODELS_RESULTS[name]
        r = pd.DataFrame(_RESULTS)
        r['section']=name
        frames.append(r)
    result = pd.concat(frames)
    result.reset_index(level=0, inplace=True)
    result=result.rename(columns={"index": "name"})
    melted_result=pd.melt(result, id_vars=['name','section'], value_vars=['train','validation','test'], var_name='type', value_name='result')
    return melted_result

# %%
# retrive single model results from notebook
# %store -r EAIRLY_FUSION_RESULTS 
# %store -r LATE_FUSION_RESULTS 
# %store -r ENSEMBLE_RESULTS

# %%
frames=[]
_result = pd.DataFrame(SINGLE_MODELS_RESULTS)
_columns=_result.columns.values
for i in enumerate(_columns):
    name = i[1]
    _RESULTS=TEST_MODELS_RESULTS[name]
    r = pd.DataFrame(_RESULTS)
    r['section']=name
    frames.append(r)
    result = pd.concat(frames)
    result.reset_index(level=0, inplace=True)
    result=result.rename(columns={"index": "name"})
    melted_result=pd.melt(result, id_vars=['name','section'], value_vars=['train','validation','test'], var_name='type', value_name='result')
melted_result

# %%
SINGLE_MODELS_RESULTS
# Out:
#          name            section        type    result
# 0        loss  SINGLE-IMBALANCED       train  0.354996
# 1    accuracy  SINGLE-IMBALANCED       train  0.893008
# 2   precision  SINGLE-IMBALANCED       train  0.961447
# 3      recall  SINGLE-IMBALANCED       train  0.843954
# 4         auc  SINGLE-IMBALANCED       train  0.995908
# 5         prc  SINGLE-IMBALANCED       train  0.971706
# 6        loss    SINGLE-BALANCED       train  0.354996
# 7    accuracy    SINGLE-BALANCED       train  0.893008
# 8   precision    SINGLE-BALANCED       train  0.961447
# 9      recall    SINGLE-BALANCED       train  0.843954
# 10        auc    SINGLE-BALANCED       train  0.995908
# 11        prc    SINGLE-BALANCED       train  0.971706
# 12       loss  SINGLE-IMBALANCED  validation  0.483863
# 13   accuracy  SINGLE-IMBALANCED  validation  0.844659
# 14  precision  SINGLE-IMBALANCED  validation  0.917067
# 15     recall  SINGLE-IMBALANCED  validation  0.799113
# ...

# %%
alt.Chart(melted_result, title="Result on type").mark_bar().encode(
  y='type',
  x='result',
  color='type',
    row='name',
    column='section',
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(melted_result, title="Result on section").mark_bar().encode(
  y='section',
  x='result',
  color='type',
  row='name',
  column='type',
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(melted_result, title="Result on train").mark_bar().encode(
  y='section',
  x=alt.X('result', stack="normalize"),
  color='type',
  row='name',
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(melted_result, title="Result on name").mark_bar().encode(
  y='name',
  x=alt.X('result', stack="normalize"),
  color='type',
  row='section',
)
# Out:
# alt.Chart(...)
