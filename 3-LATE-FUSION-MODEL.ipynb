# %%
# pip install -q -U keras-tuner

# %%
import numpy as np
import pandas as pd
import altair as alt
import tensorflow as tf
print(tf.__version__)
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from scipy.stats import chi2_contingency
from collections import Counter
from imblearn.over_sampling import SMOTE
import keras_tuner as kt
# Out:
# 2.7.0

# %%
# import dataset into colab
# %store -r IMBALANCED_TRAIN_VAL 
# %store -r RESAMPLED_TRAIN_VAL 
# %store -r TEST 
imbalanced_train_val=IMBALANCED_TRAIN_VAL.copy()
resampled_train_val= RESAMPLED_TRAIN_VAL.copy()
test= TEST.copy()

# %%
# Drop unwanted  columns
print(imbalanced_train_val.shape, 'imbalanced_train_val examples')
print(resampled_train_val.shape, 'resampled_train_val examples')
print(test.shape, 'test examples')
# Out:
# (82332, 43) imbalanced_train_val examples
# (370000, 43) resampled_train_val examples
# (175341, 43) test examples

# %%
imbalanced_train,imbalanced_val = train_test_split(imbalanced_train_val, test_size=0.2, random_state = 1)
resampled_train,resampled_val = train_test_split(resampled_train_val, test_size=0.2, random_state = 1)
CLASSES=['Normal','Generic', 'Exploits', 'Fuzzers', 'DoS', 'Backdoor', 'Reconnaissance', 'Analysis', 'Shellcode', 'Worms']
BATCH_SIZE = 32
EPOCHS = 100
MODELS_RESULTS={}
N_TRAIN=len(imbalanced_train)
N_RES_TRAIN=len(resampled_train)
N_VAL=len(imbalanced_val)
N_RES_VAL=len(resampled_val)
N_TEST=len(test)
print('___TEST________________________________________________')
print(test.shape, 'test shape')
print(N_TEST, 'test count')
print('________________________________________________________')
print('___IMBALANCED___________________________________________')
print(imbalanced_train_val.shape, 'training shape')
print(N_TRAIN, 'training examples')
print(N_VAL, 'validation examples')
print('_________________________________________________________')
print('___BALANCED______________________________________________')
print(resampled_train_val.shape, 'training shape')
print(N_RES_TRAIN, 'training examples')
print(N_RES_VAL, 'validation examples')
print('_________________________________________________________')
print(CLASSES)
# Out:
# ___TEST________________________________________________
# (175341, 43) test shape
# 175341 test count
# ________________________________________________________
# ___IMBALANCED___________________________________________
# (82332, 43) training shape
# 65865 training examples
# 16467 validation examples
# _________________________________________________________
# ___BALANCED______________________________________________
# (370000, 43) training shape
# 296000 training examples
# 74000 validation examples
# _________________________________________________________
# ['Normal', 'Generic', 'Exploits', 'Fuzzers', 'DoS', 'Backdoor', 'Reconnaissance', 'Analysis', 'Shellcode', 'Worms']

# %%
METRICS = [
      keras.metrics.CategoricalAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc'),
      keras.metrics.AUC(name='prc', curve='PR'), # precision-recall curve
]
# Out:
# 2021-12-20 15:45:15.424094: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
regularizers=tf.keras.regularizers.l2(0.001)
def group_dtype(data):
    # data=data.drop(columns=DROP_COL)
    columns=data.columns # get list of columns
    unique=data.dtypes.unique() # select one of each dtype
    result={'number_col':[],'string_category_col':[],'int_category_col':[],'labels':[]}
    for col in columns:
        if col=='attack_cat': 
            temp= result['labels'] # init array
        elif data[col].dtypes=='float64': 
            temp= result['number_col'] # init array
        elif data[col].dtypes=='int64':
             temp= result['int_category_col'] # init array
        else:
            temp= result['string_category_col'] # init array
        temp.append(col) # append the array
    return result
    
def plot_model_graph(history,name):
    plt.figure(figsize=(8, 30))
    names =['loss','accuracy','precision','recall','prc','auc']
    c=0
    for n in names:
        c=c+1
        n_val = 'val_'+n
        hist = history.history[n]
        hist_val = history.history[n_val]
        plt.subplot(len(names),1,c)
        plt.plot(hist, label='Training {}'.format(n))
        plt.plot(hist_val, label='Validation {}'.format(n))
        plt.legend(loc='lower right')
        plt.ylabel(n)
        plt.ylim(0.4,1)
        plt.title('{} Training and Validation {}'.format(name,n))
    plt.xlabel('epoch')
    return plt

def dataframe_to_dataset(dataframe):
    attack_cat=dataframe.pop('attack_cat')
    x_num=tf.convert_to_tensor(dataframe[number_col])
    x_string=tf.convert_to_tensor(dataframe[string_category_col])
    x_int=tf.convert_to_tensor(dataframe[int_category_col])
    attack_cat = attack_cat.map(CLASSES.index)
    y=tf.keras.utils.to_categorical(attack_cat, num_classes=10)
    return [x_num,x_string,x_int],y

# %%
_col = group_dtype(imbalanced_train) # return result from
number_col=_col['number_col']
string_category_col=_col['string_category_col']
int_category_col=_col['int_category_col']

# %%
dataframe = imbalanced_train.copy()
_ds= dataframe_to_dataset(dataframe)
X,y=_ds
input_num_shape = X[0].shape[1:]
input_string_shape = X[1].shape[1:]
input_int_shape = X[2].shape[1:]
classes = 10
# Create a Normalization layer and set its internal state using the training data
normalizer = layers.experimental.preprocessing.Normalization()
normalizer.adapt(X[0])
# Create a Intlookup layer and set its internal state using the training data
string_lookup = layers.StringLookup(output_mode="multi_hot")
string_lookup.adapt(X[1])
string_vocabulary=string_lookup.get_vocabulary()
# Create a Intlookup layer and set its internal state using the training data
int_lookup = layers.IntegerLookup( output_mode="multi_hot")
int_lookup.adapt(X[2])
int_vocabulary=int_lookup.get_vocabulary()

# %%
def evaluation(model,train_ds,val_ds,test_ds,name):
    X_train,y_train=train_ds
    X_val,y_val=val_ds
    X_test,y_test=test_ds
    project_name='HYPERPARAM_'+name
    tuner = kt.Hyperband(model,
                     objective='val_accuracy',
                     max_epochs=10,
                     factor=3,
                     directory='hyperparam_dir',
                     project_name=project_name)
    
    
    stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)
    
    tuner.search(X_train, y_train, epochs=50, validation_data=[X_val,y_val], callbacks=[stop_early])
    # Get the optimal hyperparameters
    best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

    print(f"""
    The hyperparameter search is complete for {name}. The optimal learning rate for the optimizer
    is {best_hps.get('learning_rate')}.
    """)
    summary=tuner.results_summary(num_trials=1)
    print("summary data")
    print(summary)
    best_model=tuner.get_best_models(num_models=1)
    print("best model data")
    # Build the model with the optimal hyperparameters and train it on the data for 50 epochs
    model = tuner.hypermodel.build(best_hps)
    print('fit model for:{}_____________________________________________________________________________________________________________'.format(name))
    history = model.fit(X_train,y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, validation_data=[X_val,y_val])
    val_acc_per_epoch = history.history['val_accuracy']
    best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
    print('Best epoch: %d' % (best_epoch,))
#   Re-instantiate the hypermodel and train it with the optimal number of epochs from above.
    hypermodel = tuner.hypermodel.build(best_hps)
    # Retrain the model
    print('fit model for:{}_____________________________________________________________________________________________________________'.format(name))
    history = hypermodel.fit(X_train,y_train, batch_size=BATCH_SIZE, epochs=best_epoch, validation_data=[X_val,y_val])
    MODELS_RESULTS[name]={}
    print('----')
    print('----')
    print('evaluation result model for:{} on TRAIN_________________________________________________________'.format(name))
    loss,accuracy,precision,recall,auc,prc = hypermodel.evaluate(X_train,y_train)
    MODELS_RESULTS[name]['train']={'loss':loss,'accuracy':accuracy,'precision':precision,'recall':recall,'auc':auc,'prc':prc}
    print('loss:{} -accuracy:{} - precision:{} - recall:{} - auc:{} - prc:{}'.format(loss,accuracy,precision,recall,auc,prc))
    print('----')
    print('----')
    print('evaluation result model for:{} on VALIDATION________________________________________________________________________________'.format(name))
    loss,accuracy,precision,recall,auc,prc = hypermodel.evaluate(X_val,y_val)
    MODELS_RESULTS[name]['validation']={'loss':loss,'accuracy':accuracy,'precision':precision,'recall':recall,'auc':auc,'prc':prc}
    print('loss:{} -accuracy:{} - precision:{} - recall:{} - auc:{} - prc:{}'.format(loss,accuracy,precision,recall,auc,prc))
    print('----')
    print('----')
    print('evaluation result model for:{} on TEST________________________________________________________________________________'.format(name))
    loss,accuracy,precision,recall,auc,prc = hypermodel.evaluate(X_test,y_test)
    MODELS_RESULTS[name]['test']={'loss':loss,'accuracy':accuracy,'precision':precision,'recall':recall,'auc':auc,'prc':prc}
    print('loss:{} -accuracy:{} - precision:{} - recall:{} - auc:{} - prc:{}'.format(loss,accuracy,precision,recall,auc,prc))
    print('----')
    print('----')
    print('plot:{}_________________________________________________________'.format(name))
    plot_model_graph(history,name)
    return hypermodel

# %%
# # Load some data
def build_model(hp):
    # Tune the number of units in the first Dense layer
    # Choose an optimal value between 32-512
    # Tune the learning rate for the optimizer
    # Choose an optimal value from 0.01, 0.001, or 0.0001
    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])
    
    # Input layer for numeric data
    input_num = keras.Input(shape=input_num_shape, name='numeric_inputs')
    # include the normalization layer
    x1 = normalizer(input_num)
    # dence layers for numeric data
    hp_units_num_1 = hp.Int('units_num_1', min_value=32, max_value=512, step=32)
    x1 = layers.Dense(units=hp_units_num_1,activation='relu',kernel_regularizer=regularizers)(x1)
    x1 = layers.Dropout(0.5)(x1)
    
    hp_units_num_2 = hp.Int('units_num_2', min_value=32, max_value=512, step=32)
    x1 = layers.Dense(units=hp_units_num_2,activation='relu',kernel_regularizer=regularizers)(x1)
    x1 = layers.Dropout(0.5)(x1)
    
    hp_units_num_3 = hp.Int('units_num_3', min_value=32, max_value=512, step=32)
    x1 = layers.Dense(units=hp_units_num_3,activation='relu',kernel_regularizer=regularizers)(x1)
    x1 = layers.Dropout(0.5)(x1)
    
    output_num = layers.Dense(128,activation='relu',kernel_regularizer=regularizers)(x1)
    model_1=keras.models.Model(inputs=input_num, outputs=output_num)
    print('SUBMODAL-INTEGER-NUMERIC')
    model_1.summary()
    y1= model_1(input_num)
    
  # Input layer for integer cartegory data
    input_int = keras.Input(shape=input_int_shape, name='cartegory_integer_inputs')
  # include the int_lookup layer
    x2 = int_lookup(input_int)
  # dence layers for integer data
    hp_units_int_1 = hp.Int('units_int_1', min_value=32, max_value=512, step=32)
    x2 = layers.Dense(units=hp_units_int_1,activation='relu',kernel_regularizer=regularizers)(x2)
    x2 = layers.Dropout(0.5)(x2)
    
    hp_units_int_2 = hp.Int('units_int_2', min_value=32, max_value=512, step=32)
    x2 = layers.Dense(units=hp_units_int_2,activation='relu',kernel_regularizer=regularizers)(x2)
    x2 = layers.Dropout(0.5)(x2)
    
    hp_units_int_3 = hp.Int('units_int_3', min_value=32, max_value=512, step=32)
    x2 = layers.Dense(units=hp_units_int_3,activation='relu',kernel_regularizer=regularizers)(x2)
    x2 = layers.Dropout(0.5)(x2)

    output_int = layers.Dense(128,activation='relu',kernel_regularizer=regularizers)(x2)
    model_2=keras.models.Model(inputs=input_int, outputs=output_int)
    print('SUBMODAL-INTEGER-SUMMARY')
    model_2.summary()
    y2= model_2(input_int)
    
  # Input layer for string cartegory data
    input_string = keras.Input(shape=input_string_shape, name='cartegory_string_inputs',dtype='string')
  # include the int_lookup layer
    x3 = string_lookup(input_string)
  # dence layers for string data
    hp_units_string_1 = hp.Int('units_string_1', min_value=32, max_value=512, step=32)
    x3 = layers.Dense(units=hp_units_string_1,activation='relu',kernel_regularizer=regularizers)(x3)
    x3 = layers.Dropout(0.5)(x3)
    
    hp_units_string_2 = hp.Int('units_string_2', min_value=32, max_value=512, step=32)
    x3 = layers.Dense(units=hp_units_string_2,activation='relu',kernel_regularizer=regularizers)(x3)
    x3 = layers.Dropout(0.5)(x3)
    
    
    hp_units_string_3 = hp.Int('units_string_3', min_value=32, max_value=512, step=32)
    x3 = layers.Dense(units=hp_units_string_3,activation='relu',kernel_regularizer=regularizers)(x3)
    x3 = layers.Dropout(0.5)(x3)
    
    output_string = layers.Dense(128,activation='relu',kernel_regularizer=regularizers)(x3)
    model_3=keras.models.Model(inputs=input_string, outputs=output_string)
    print('SUBMODAL-STRING-SUMMARY')
    model_3.summary()
    y3= model_3(input_string)
    
    avg = tf.keras.layers.Average()([y1,y2,y3])
    output = layers.Dense(classes, activation="softmax")(avg)
    model = keras.Model(inputs=[input_num,input_string,input_int], outputs=output)
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=hp_learning_rate), loss=keras.losses.CategoricalCrossentropy(), metrics=METRICS)
    return model

# %%
# LATE-FUSION-IMBALANCED
dataframe = imbalanced_train.copy()
train_ds= dataframe_to_dataset(dataframe)
dataframe = imbalanced_val.copy()
val_ds= dataframe_to_dataset(dataframe)
dataframe = test.copy()
test_ds= dataframe_to_dataset(dataframe)

print('LATE-FUSION-IMBALANCED')
model= evaluation(build_model,train_ds,val_ds,test_ds,'LATE-FUSION-IMBALANCED')
# Out:
# LATE-FUSION-IMBALANCED
# INFO:tensorflow:Reloading Oracle from existing project hyperparam_dir/HYPERPARAM_LATE-FUSION-IMBALANCED/oracle.json
# SUBMODAL-INTEGER-NUMERIC
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  numeric_inputs (InputLayer)  [(None, 11)]             0
#
#  normalization (Normalizatio  (None, 11)               23
#  n)
#
#  dense_26 (Dense)            (None, 32)                384
#
#  dropout_18 (Dropout)        (None, 32)                0
#
#  dense_27 (Dense)            (None, 32)                1056
#
#  dropout_19 (Dropout)        (None, 32)                0
#
#  dense_28 (Dense)            (None, 32)                1056
#
#  dropout_20 (Dropout)        (None, 32)                0
#
#  dense_29 (Dense)            (None, 128)               4224
#
# =================================================================
# Total params: 6,743
# Trainable params: 6,720
# Non-trainable params: 23
# _________________________________________________________________
# SUBMODAL-INTEGER-SUMMARY
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  cartegory_integer_inputs (I  [(None, 28)]             0
#  nputLayer)
#
#  integer_lookup (IntegerLook  (None, 70605)            0
#  up)
#
#  dense_30 (Dense)            (None, 32)                2259392
#
#  dropout_21 (Dropout)        (None, 32)                0
#
#  dense_31 (Dense)            (None, 32)                1056
#
#  dropout_22 (Dropout)        (None, 32)                0
#
#  dense_32 (Dense)            (None, 32)                1056
#
#  dropout_23 (Dropout)        (None, 32)                0
#
#  dense_33 (Dense)            (None, 128)               4224
#
# =================================================================
# Total params: 2,265,728
# Trainable params: 2,265,728
# Non-trainable params: 0
# _________________________________________________________________
# SUBMODAL-STRING-SUMMARY
# Model: "model_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  cartegory_string_inputs (In  [(None, 3)]              0
#  putLayer)
#
#  string_lookup (StringLookup  (None, 152)              0
#  )
#
#  dense_34 (Dense)            (None, 32)                4896
#
#  dropout_24 (Dropout)        (None, 32)                0
#
#  dense_35 (Dense)            (None, 32)                1056
#
#  dropout_25 (Dropout)        (None, 32)                0
#
#  dense_36 (Dense)            (None, 32)                1056
#
#  dropout_26 (Dropout)        (None, 32)                0
#
#  dense_37 (Dense)            (None, 128)               4224
#
# =================================================================
# Total params: 11,232
# Trainable params: 11,232
# Non-trainable params: 0
# _________________________________________________________________
# INFO:tensorflow:Reloading Tuner from hyperparam_dir/HYPERPARAM_LATE-FUSION-IMBALANCED/tuner0.json
# INFO:tensorflow:Oracle triggered exit
#
#     The hyperparameter search is complete for LATE-FUSION-IMBALANCED. The optimal learning rate for the optimizer
#     is 0.0001.
#
# Results summary
# Results in hyperparam_dir/HYPERPARAM_LATE-FUSION-IMBALANCED
# Showing 1 best trials
# Objective(name='val_accuracy', direction='max')
# Trial summary
# Hyperparameters:
# learning_rate: 0.0001
# units_num_1: 256
# units_num_2: 416
# units_num_3: 96
# units_int_1: 288
# units_int_2: 256
# units_int_3: 480
# units_string_1: 192
# units_string_2: 192
# units_string_3: 512
# tuner/epochs: 10
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.8252261877059937
# summary data
# None
# SUBMODAL-INTEGER-NUMERIC
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  numeric_inputs (InputLayer)  [(None, 11)]             0
#
#  normalization (Normalizatio  (None, 11)               23
#  n)
#
#  dense (Dense)               (None, 256)               3072
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 416)               106912
#
#  dropout_1 (Dropout)         (None, 416)               0
#
#  dense_2 (Dense)             (None, 96)                40032
#
#  dropout_2 (Dropout)         (None, 96)                0
#
#  dense_3 (Dense)             (None, 128)               12416
#
# =================================================================
# Total params: 162,455
# Trainable params: 162,432
# Non-trainable params: 23
# _________________________________________________________________
# SUBMODAL-INTEGER-SUMMARY
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  cartegory_integer_inputs (I  [(None, 28)]             0
#  nputLayer)
#
#  integer_lookup (IntegerLook  (None, 70605)            0
#  up)
#
#  dense_4 (Dense)             (None, 288)               20334528
#
#  dropout_3 (Dropout)         (None, 288)               0
#
#  dense_5 (Dense)             (None, 256)               73984
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_6 (Dense)             (None, 480)               123360
#
#  dropout_5 (Dropout)         (None, 480)               0
#
#  dense_7 (Dense)             (None, 128)               61568
#
# =================================================================
# Total params: 20,593,440
# Trainable params: 20,593,440
# Non-trainable params: 0
# _________________________________________________________________
# SUBMODAL-STRING-SUMMARY
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  cartegory_string_inputs (In  [(None, 3)]              0
#  putLayer)
#
#  string_lookup (StringLookup  (None, 152)              0
#  )
#
#  dense_8 (Dense)             (None, 192)               29376
#
#  dropout_6 (Dropout)         (None, 192)               0
#
#  dense_9 (Dense)             (None, 192)               37056
#
#  dropout_7 (Dropout)         (None, 192)               0
#
#  dense_10 (Dense)            (None, 512)               98816
#
#  dropout_8 (Dropout)         (None, 512)               0
#
#  dense_11 (Dense)            (None, 128)               65664
#
# =================================================================
# Total params: 230,912
# Trainable params: 230,912
# Non-trainable params: 0
# _________________________________________________________________
# best model data
# SUBMODAL-INTEGER-NUMERIC
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  numeric_inputs (InputLayer)  [(None, 11)]             0
#
#  normalization (Normalizatio  (None, 11)               23
#  n)
#
#  dense_13 (Dense)            (None, 256)               3072
#
#  dropout_9 (Dropout)         (None, 256)               0
#
#  dense_14 (Dense)            (None, 416)               106912
#
#  dropout_10 (Dropout)        (None, 416)               0
#
#  dense_15 (Dense)            (None, 96)                40032
#
#  dropout_11 (Dropout)        (None, 96)                0
#
#  dense_16 (Dense)            (None, 128)               12416
#
# =================================================================
# Total params: 162,455
# Trainable params: 162,432
# Non-trainable params: 23
# _________________________________________________________________
# SUBMODAL-INTEGER-SUMMARY
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  cartegory_integer_inputs (I  [(None, 28)]             0
#  nputLayer)
#
#  integer_lookup (IntegerLook  (None, 70605)            0
#  up)
#
#  dense_17 (Dense)            (None, 288)               20334528
#
#  dropout_12 (Dropout)        (None, 288)               0
#
#  dense_18 (Dense)            (None, 256)               73984
#
#  dropout_13 (Dropout)        (None, 256)               0
#
#  dense_19 (Dense)            (None, 480)               123360
#
#  dropout_14 (Dropout)        (None, 480)               0
#
#  dense_20 (Dense)            (None, 128)               61568
#
# =================================================================
# Total params: 20,593,440
# Trainable params: 20,593,440
# Non-trainable params: 0
# _________________________________________________________________
# SUBMODAL-STRING-SUMMARY
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  cartegory_string_inputs (In  [(None, 3)]              0
#  putLayer)
#
#  string_lookup (StringLookup  (None, 152)              0
#  )
#
#  dense_21 (Dense)            (None, 192)               29376
#
#  dropout_15 (Dropout)        (None, 192)               0
#
#  dense_22 (Dense)            (None, 192)               37056
#
#  dropout_16 (Dropout)        (None, 192)               0
#
#  dense_23 (Dense)            (None, 512)               98816
#
#  dropout_17 (Dropout)        (None, 512)               0
#
#  dense_24 (Dense)            (None, 128)               65664
#
# =================================================================
# Total params: 230,912
# Trainable params: 230,912
# Non-trainable params: 0
# _________________________________________________________________
# fit model for:LATE-FUSION-IMBALANCED_____________________________________________________________________________________________________________
# Epoch 1/100
# 2059/2059 [==============================] - 535s 252ms/step - loss: 1.8313 - accuracy: 0.7088 - precision: 0.8801 - recall: 0.5889 - auc: 0.9551 - prc: 0.8093 - val_loss: 1.0862 - val_accuracy: 0.8049 - val_precision: 0.9010 - val_recall: 0.7304 - val_auc: 0.9811 - val_prc: 0.9019
# Epoch 2/100
# 2059/2059 [==============================] - 491s 239ms/step - loss: 0.9171 - accuracy: 0.8049 - precision: 0.9048 - recall: 0.7333 - auc: 0.9818 - prc: 0.9048 - val_loss: 0.7825 - val_accuracy: 0.8107 - val_precision: 0.8928 - val_recall: 0.7519 - val_auc: 0.9836 - val_prc: 0.9115
# Epoch 3/100
# 2059/2059 [==============================] - 492s 239ms/step - loss: 0.7335 - accuracy: 0.8116 - precision: 0.9071 - recall: 0.7409 - auc: 0.9837 - prc: 0.9123 - val_loss: 0.6740 - val_accuracy: 0.8134 - val_precision: 0.9038 - val_recall: 0.7460 - val_auc: 0.9852 - val_prc: 0.9176
# Epoch 4/100
# 2059/2059 [==============================] - 549s 267ms/step - loss: 0.6628 - accuracy: 0.8154 - precision: 0.9094 - recall: 0.7479 - auc: 0.9847 - prc: 0.9166 - val_loss: 0.6294 - val_accuracy: 0.8162 - val_precision: 0.9069 - val_recall: 0.7534 - val_auc: 0.9861 - val_prc: 0.9211
# Epoch 5/100
# 2059/2059 [==============================] - 544s 264ms/step - loss: 0.6279 - accuracy: 0.8178 - precision: 0.9095 - recall: 0.7520 - auc: 0.9856 - prc: 0.9200 - val_loss: 0.6081 - val_accuracy: 0.8172 - val_precision: 0.9067 - val_recall: 0.7524 - val_auc: 0.9865 - val_prc: 0.9224
# Epoch 6/100
# 2059/2059 [==============================] - 552s 268ms/step - loss: 0.6079 - accuracy: 0.8188 - precision: 0.9116 - recall: 0.7561 - auc: 0.9861 - prc: 0.9221 - val_loss: 0.6031 - val_accuracy: 0.8181 - val_precision: 0.8959 - val_recall: 0.7652 - val_auc: 0.9859 - val_prc: 0.9218
# Epoch 7/100
# 2059/2059 [==============================] - 535s 260ms/step - loss: 0.5947 - accuracy: 0.8217 - precision: 0.9115 - recall: 0.7587 - auc: 0.9865 - prc: 0.9239 - val_loss: 0.5836 - val_accuracy: 0.8241 - val_precision: 0.9097 - val_recall: 0.7621 - val_auc: 0.9870 - val_prc: 0.9259
# Epoch 8/100
# 2059/2059 [==============================] - 544s 264ms/step - loss: 0.4805 - accuracy: 0.8520 - precision: 0.9288 - recall: 0.7992 - auc: 0.9915 - prc: 0.9475 - val_loss: 0.5088 - val_accuracy: 0.8422 - val_precision: 0.9175 - val_recall: 0.7897 - val_auc: 0.9897 - val_prc: 0.9403
# Epoch 90/100
# 2059/2059 [==============================] - 546s 265ms/step - loss: 0.4793 - accuracy: 0.8535 - precision: 0.9300 - recall: 0.8001 - auc: 0.9916 - prc: 0.9479 - val_loss: 0.5169 - val_accuracy: 0.8405 - val_precision: 0.9169 - val_recall: 0.7895 - val_auc: 0.9894 - val_prc: 0.9385
# Epoch 91/100
# 2059/2059 [==============================] - 534s 259ms/step - loss: 0.4770 - accuracy: 0.8541 - precision: 0.9302 - recall: 0.7998 - auc: 0.9917 - prc: 0.9484 - val_loss: 0.5224 - val_accuracy: 0.8380 - val_precision: 0.9111 - val_recall: 0.7886 - val_auc: 0.9889 - val_prc: 0.9374
# Epoch 92/100
# 2059/2059 [==============================] - 520s 252ms/step - loss: 0.4791 - accuracy: 0.8532 - precision: 0.9296 - recall: 0.8007 - auc: 0.9916 - prc: 0.9480 - val_loss: 0.5158 - val_accuracy: 0.8382 - val_precision: 0.9193 - val_recall: 0.7807 - val_auc: 0.9895 - val_prc: 0.9381
# Epoch 93/100
# 2059/2059 [==============================] - 490s 238ms/step - loss: 0.4795 - accuracy: 0.8532 - precision: 0.9294 - recall: 0.7996 - auc: 0.9916 - prc: 0.9478 - val_loss: 0.5127 - val_accuracy: 0.8418 - val_precision: 0.9147 - val_recall: 0.7928 - val_auc: 0.9895 - val_prc: 0.9396
# Epoch 94/100
# 2059/2059 [==============================] - 473s 230ms/step - loss: 0.4782 - accuracy: 0.8533 - precision: 0.9293 - recall: 0.8001 - auc: 0.9916 - prc: 0.9481 - val_loss: 0.5227 - val_accuracy: 0.8390 - val_precision: 0.9137 - val_recall: 0.7896 - val_auc: 0.9889 - val_prc: 0.9373
# Epoch 95/100
# 2059/2059 [==============================] - 479s 233ms/step - loss: 0.4764 - accuracy: 0.8537 - precision: 0.9301 - recall: 0.8005 - auc: 0.9917 - prc: 0.9484 - val_loss: 0.5123 - val_accuracy: 0.8402 - val_precision: 0.9201 - val_recall: 0.7859 - val_auc: 0.9896 - val_prc: 0.9395
# Epoch 96/100
# 2059/2059 [==============================] - 485s 236ms/step - loss: 0.4782 - accuracy: 0.8537 - precision: 0.9298 - recall: 0.8008 - auc: 0.9916 - prc: 0.9479 - val_loss: 0.5137 - val_accuracy: 0.8396 - val_precision: 0.9179 - val_recall: 0.7850 - val_auc: 0.9897 - val_prc: 0.9387
# Epoch 97/100
# 2059/2059 [==============================] - 488s 237ms/step - loss: 0.4778 - accuracy: 0.8545 - precision: 0.9305 - recall: 0.8011 - auc: 0.9917 - prc: 0.9482 - val_loss: 0.5160 - val_accuracy: 0.8406 - val_precision: 0.9143 - val_recall: 0.7923 - val_auc: 0.9893 - val_prc: 0.9388
# Epoch 98/100
# 2059/2059 [==============================] - 487s 237ms/step - loss: 0.4771 - accuracy: 0.8535 - precision: 0.9294 - recall: 0.8014 - auc: 0.9917 - prc: 0.9483 - val_loss: 0.5117 - val_accuracy: 0.8426 - val_precision: 0.9168 - val_recall: 0.7924 - val_auc: 0.9895 - val_prc: 0.9399
# Epoch 99/100
# 2059/2059 [==============================] - 486s 236ms/step - loss: 0.4770 - accuracy: 0.8541 - precision: 0.9297 - recall: 0.8006 - auc: 0.9917 - prc: 0.9483 - val_loss: 0.5127 - val_accuracy: 0.8405 - val_precision: 0.9168 - val_recall: 0.7890 - val_auc: 0.9896 - val_prc: 0.9393
# Epoch 100/100
# 2059/2059 [==============================] - 487s 237ms/step - loss: 0.4766 - accuracy: 0.8541 - precision: 0.9300 - recall: 0.8009 - auc: 0.9917 - prc: 0.9484 - val_loss: 0.5213 - val_accuracy: 0.8399 - val_precision: 0.9157 - val_recall: 0.7893 - val_auc: 0.9891 - val_prc: 0.9379
# Best epoch: 98
# SUBMODAL-INTEGER-NUMERIC
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  numeric_inputs (InputLayer)  [(None, 11)]             0
#
#  normalization (Normalizatio  (None, 11)               23
#  n)
#
#  dense_26 (Dense)            (None, 256)               3072
#
#  dropout_18 (Dropout)        (None, 256)               0
#
#  dense_27 (Dense)            (None, 416)               106912
#
#  dropout_19 (Dropout)        (None, 416)               0
#
#  dense_28 (Dense)            (None, 96)                40032
#
#  dropout_20 (Dropout)        (None, 96)                0
#
#  dense_29 (Dense)            (None, 128)               12416
#
# =================================================================
# Total params: 162,455
# Trainable params: 162,432
# Non-trainable params: 23
# ...
# Epoch 53/98
# 2059/2059 [==============================] - 540s 262ms/step - loss: 0.4950 - accuracy: 0.8475 - precision: 0.9265 - recall: 0.7954 - auc: 0.9907 - prc: 0.9435 - val_loss: 0.5183 - val_accuracy: 0.8399 - val_precision: 0.9189 - val_recall: 0.7865 - val_auc: 0.9891 - val_prc: 0.9373
# Epoch 54/98
# 2059/2059 [==============================] - 525s 255ms/step - loss: 0.4949 - accuracy: 0.8467 - precision: 0.9270 - recall: 0.7947 - auc: 0.9907 - prc: 0.9434 - val_loss: 0.5152 - val_accuracy: 0.8386 - val_precision: 0.9193 - val_recall: 0.7851 - val_auc: 0.9894 - val_prc: 0.9377
# Epoch 55/98
# 2059/2059 [==============================] - 519s 252ms/step - loss: 0.4934 - accuracy: 0.8476 - precision: 0.9284 - recall: 0.7957 - auc: 0.9908 - prc: 0.9439 - val_loss: 0.5149 - val_accuracy: 0.8391 - val_precision: 0.9182 - val_recall: 0.7864 - val_auc: 0.9894 - val_prc: 0.9381
# Epoch 56/98
# 2059/2059 [==============================] - 546s 265ms/step - loss: 0.4924 - accuracy: 0.8486 - precision: 0.9275 - recall: 0.7956 - auc: 0.9907 - prc: 0.9440 - val_loss: 0.5166 - val_accuracy: 0.8376 - val_precision: 0.9185 - val_recall: 0.7830 - val_auc: 0.9895 - val_prc: 0.9372
# Epoch 57/98
# 2059/2059 [==============================] - 534s 259ms/step - loss: 0.4790 - accuracy: 0.8531 - precision: 0.9318 - recall: 0.8015 - auc: 0.9914 - prc: 0.9471 - val_loss: 0.5135 - val_accuracy: 0.8394 - val_precision: 0.9162 - val_recall: 0.7904 - val_auc: 0.9893 - val_prc: 0.9382
# Epoch 85/98
# 2059/2059 [==============================] - 547s 266ms/step - loss: 0.4782 - accuracy: 0.8514 - precision: 0.9307 - recall: 0.8000 - auc: 0.9914 - prc: 0.9470 - val_loss: 0.5113 - val_accuracy: 0.8393 - val_precision: 0.9165 - val_recall: 0.7896 - val_auc: 0.9894 - val_prc: 0.9386
# Epoch 86/98
# 2059/2059 [==============================] - 547s 266ms/step - loss: 0.4780 - accuracy: 0.8515 - precision: 0.9317 - recall: 0.8007 - auc: 0.9913 - prc: 0.9472 - val_loss: 0.5083 - val_accuracy: 0.8407 - val_precision: 0.9206 - val_recall: 0.7864 - val_auc: 0.9897 - val_prc: 0.9395
# Epoch 87/98
# 2059/2059 [==============================] - 512s 248ms/step - loss: 0.4764 - accuracy: 0.8525 - precision: 0.9322 - recall: 0.8012 - auc: 0.9915 - prc: 0.9476 - val_loss: 0.5081 - val_accuracy: 0.8406 - val_precision: 0.9206 - val_recall: 0.7889 - val_auc: 0.9894 - val_prc: 0.9393
# Epoch 88/98
# 2059/2059 [==============================] - 551s 267ms/step - loss: 0.4757 - accuracy: 0.8536 - precision: 0.9320 - recall: 0.8017 - auc: 0.9915 - prc: 0.9478 - val_loss: 0.5129 - val_accuracy: 0.8374 - val_precision: 0.9155 - val_recall: 0.7885 - val_auc: 0.9895 - val_prc: 0.9381
# Epoch 89/98
# 2059/2059 [==============================] - 539s 262ms/step - loss: 0.4772 - accuracy: 0.8528 - precision: 0.9320 - recall: 0.8012 - auc: 0.9915 - prc: 0.9474 - val_loss: 0.5055 - val_accuracy: 0.8406 - val_precision: 0.9204 - val_recall: 0.7889 - val_auc: 0.9899 - val_prc: 0.9399
# Epoch 90/98
# 2059/2059 [==============================] - 530s 257ms/step - loss: 0.4760 - accuracy: 0.8525 - precision: 0.9309 - recall: 0.8017 - auc: 0.9915 - prc: 0.9476 - val_loss: 0.5104 - val_accuracy: 0.8391 - val_precision: 0.9161 - val_recall: 0.7892 - val_auc: 0.9896 - val_prc: 0.9384
# Epoch 91/98
# 2059/2059 [==============================] - 498s 242ms/step - loss: 0.4752 - accuracy: 0.8526 - precision: 0.9319 - recall: 0.8020 - auc: 0.9916 - prc: 0.9478 - val_loss: 0.5077 - val_accuracy: 0.8383 - val_precision: 0.9214 - val_recall: 0.7847 - val_auc: 0.9898 - val_prc: 0.9392
# Epoch 92/98
# 2059/2059 [==============================] - 505s 245ms/step - loss: 0.4731 - accuracy: 0.8543 - precision: 0.9332 - recall: 0.8027 - auc: 0.9916 - prc: 0.9484 - val_loss: 0.5098 - val_accuracy: 0.8420 - val_precision: 0.9216 - val_recall: 0.7912 - val_auc: 0.9895 - val_prc: 0.9392
# Epoch 93/98
# 2059/2059 [==============================] - 524s 254ms/step - loss: 0.4764 - accuracy: 0.8506 - precision: 0.9314 - recall: 0.8010 - auc: 0.9915 - prc: 0.9474 - val_loss: 0.5067 - val_accuracy: 0.8393 - val_precision: 0.9205 - val_recall: 0.7873 - val_auc: 0.9898 - val_prc: 0.9398
# Epoch 94/98
# 2059/2059 [==============================] - 496s 241ms/step - loss: 0.4742 - accuracy: 0.8536 - precision: 0.9326 - recall: 0.8018 - auc: 0.9916 - prc: 0.9481 - val_loss: 0.5071 - val_accuracy: 0.8392 - val_precision: 0.9214 - val_recall: 0.7848 - val_auc: 0.9898 - val_prc: 0.9394
# Epoch 95/98
# 2059/2059 [==============================] - 486s 236ms/step - loss: 0.4737 - accuracy: 0.8531 - precision: 0.9321 - recall: 0.8024 - auc: 0.9916 - prc: 0.9483 - val_loss: 0.5100 - val_accuracy: 0.8402 - val_precision: 0.9178 - val_recall: 0.7916 - val_auc: 0.9895 - val_prc: 0.9393
# Epoch 96/98
# 2059/2059 [==============================] - 499s 242ms/step - loss: 0.4740 - accuracy: 0.8534 - precision: 0.9316 - recall: 0.8007 - auc: 0.9916 - prc: 0.9481 - val_loss: 0.5086 - val_accuracy: 0.8402 - val_precision: 0.9173 - val_recall: 0.7909 - val_auc: 0.9896 - val_prc: 0.9391
# Epoch 97/98
# 2059/2059 [==============================] - 496s 241ms/step - loss: 0.4722 - accuracy: 0.8532 - precision: 0.9326 - recall: 0.8019 - auc: 0.9917 - prc: 0.9484 - val_loss: 0.5061 - val_accuracy: 0.8417 - val_precision: 0.9214 - val_recall: 0.7891 - val_auc: 0.9898 - val_prc: 0.9399
# Epoch 98/98
# 2059/2059 [==============================] - 505s 245ms/step - loss: 0.4728 - accuracy: 0.8536 - precision: 0.9331 - recall: 0.8029 - auc: 0.9917 - prc: 0.9485 - val_loss: 0.5121 - val_accuracy: 0.8393 - val_precision: 0.9149 - val_recall: 0.7921 - val_auc: 0.9894 - val_prc: 0.9384
# ----
# ----
# evaluation result model for:LATE-FUSION-IMBALANCED on TRAIN_________________________________________________________
# 2059/2059 [==============================] - 104s 51ms/step - loss: 0.4429 - accuracy: 0.8593 - precision: 0.9354 - recall: 0.8146 - auc: 0.9930 - prc: 0.9547
# loss:0.44294071197509766 -accuracy:0.8592727780342102 - precision:0.935438334941864 - recall:0.8145904541015625 - auc:0.9929890036582947 - prc:0.9546872973442078
# ----
# ----
# evaluation result model for:LATE-FUSION-IMBALANCED on VALIDATION________________________________________________________________________________
# 515/515 [==============================] - 26s 50ms/step - loss: 0.5121 - accuracy: 0.8393 - precision: 0.9149 - recall: 0.7921 - auc: 0.9894 - prc: 0.9384
# loss:0.5120823383331299 -accuracy:0.8392542600631714 - precision:0.9149129986763 - recall:0.7920689582824707 - auc:0.9894083738327026 - prc:0.938427209854126
# ----
# ----
# evaluation result model for:LATE-FUSION-IMBALANCED on TEST________________________________________________________________________________
# 5480/5480 [==============================] - 279s 51ms/step - loss: 0.7311 - accuracy: 0.7710 - precision: 0.8604 - recall: 0.6950 - auc: 0.9763 - prc: 0.8823
# loss:0.7310816049575806 -accuracy:0.7709833979606628 - precision:0.8604015707969666 - recall:0.6950399279594421 - auc:0.9763052463531494 - prc:0.8822578191757202
# ----
# ----
# plot:LATE-FUSION-IMBALANCED_________________________________________________________
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.

# %%
# LATE-FUSION-BALANCED
dataframe = resampled_train.copy()
train_ds= dataframe_to_dataset(dataframe)
dataframe = resampled_val.copy()
val_ds= dataframe_to_dataset(dataframe)
dataframe = test.copy()
test_ds= dataframe_to_dataset(dataframe)
print('LATE-FUSION-BALANCED')
model= evaluation(build_model,train_ds,val_ds,test_ds,'LATE-FUSION-BALANCED')
# Out:
# Trial 27 Complete [04h 58m 40s]
# val_accuracy: 0.6924864649772644
#
# Best val_accuracy So Far: 0.6924864649772644
# Total elapsed time: 20h 08m 06s
#
# Search: Running Trial #28
#
# Hyperparameter    |Value             |Best Value So Far
# learning_rate     |0.0001            |0.0001
# units_num_1       |160               |128
# units_num_2       |512               |512
# units_num_3       |64                |384
# units_int_1       |224               |384
# units_int_2       |128               |96
# units_int_3       |192               |320
# units_string_1    |64                |288
# units_string_2    |416               |64
# units_string_3    |416               |288
# tuner/epochs      |10                |10
# tuner/initial_e...|0                 |4
# tuner/bracket     |0                 |1
# tuner/round       |0                 |1
#
# SUBMODAL-INTEGER-NUMERIC
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  numeric_inputs (InputLayer)  [(None, 11)]             0
#
#  normalization (Normalizatio  (None, 11)               23
#  n)
#
#  dense (Dense)               (None, 160)               1920
#
#  dropout (Dropout)           (None, 160)               0
#
#  dense_1 (Dense)             (None, 512)               82432
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 64)                32832
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 128)               8320
#
# =================================================================
# Total params: 125,527
# Trainable params: 125,504
# Non-trainable params: 23
# _________________________________________________________________
# SUBMODAL-INTEGER-SUMMARY
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  cartegory_integer_inputs (I  [(None, 28)]             0
#  nputLayer)
#
#  integer_lookup (IntegerLook  (None, 70605)            0
#  up)
#
#  dense_4 (Dense)             (None, 224)               15815744
#
#  dropout_3 (Dropout)         (None, 224)               0
#
#  dense_5 (Dense)             (None, 128)               28800
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_6 (Dense)             (None, 192)               24768
#
#  dropout_5 (Dropout)         (None, 192)               0
#
#  dense_7 (Dense)             (None, 128)               24704
#
# =================================================================
# Total params: 15,894,016
# Trainable params: 15,894,016
# Non-trainable params: 0
# _________________________________________________________________
# SUBMODAL-STRING-SUMMARY
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  cartegory_string_inputs (In  [(None, 3)]              0
#  putLayer)
#
#  string_lookup (StringLookup  (None, 152)              0
#  )
#
#  dense_8 (Dense)             (None, 64)                9792
#
#  dropout_6 (Dropout)         (None, 64)                0
#
#  dense_9 (Dense)             (None, 416)               27040
#
#  dropout_7 (Dropout)         (None, 416)               0
#
#  dense_10 (Dense)            (None, 416)               173472
#
#  dropout_8 (Dropout)         (None, 416)               0
#
#  dense_11 (Dense)            (None, 128)               53376
#
# =================================================================
# Total params: 263,680
# Trainable params: 263,680
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 9250/9250 [==============================] - 1751s 188ms/step - loss: 1.5839 - accuracy: 0.5973 - precision: 0.8599 - recall: 0.4000 - auc: 0.9346 - prc: 0.7074 - val_loss: 1.1453 - val_accuracy: 0.6367 - val_precision: 0.8516 - val_recall: 0.4727 - val_auc: 0.9510 - val_prc: 0.7591
# Epoch 2/10
# 9250/9250 [==============================] - 1739s 188ms/step - loss: 1.1209 - accuracy: 0.6475 - precision: 0.8507 - recall: 0.4755 - auc: 0.9510 - prc: 0.7599 - val_loss: 1.0357 - val_accuracy: 0.6618 - val_precision: 0.8580 - val_recall: 0.5085 - val_auc: 0.9577 - val_prc: 0.7851
# Epoch 3/10
# 9250/9250 [==============================] - 1805s 195ms/step - loss: 1.0526 - accuracy: 0.6622 - precision: 0.8553 - recall: 0.4986 - auc: 0.9557 - prc: 0.7778 - val_loss: 0.9921 - val_accuracy: 0.6791 - val_precision: 0.8682 - val_recall: 0.5208 - val_auc: 0.9610 - val_prc: 0.7989
# Epoch 4/10
# 9250/9250 [==============================] - 1950s 211ms/step - loss: 1.0217 - accuracy: 0.6721 - precision: 0.8575 - recall: 0.5090 - auc: 0.9579 - prc: 0.7866 - val_loss: 0.9713 - val_accuracy: 0.6852 - val_precision: 0.8715 - val_recall: 0.5247 - val_auc: 0.9623 - val_prc: 0.8043
# Epoch 5/10
# 9250/9250 [==============================] - 1871s 202ms/step - loss: 1.0004 - accuracy: 0.6780 - precision: 0.8594 - recall: 0.5161 - auc: 0.9594 - prc: 0.7927 - val_loss: 0.9551 - val_accuracy: 0.6888 - val_precision: 0.8663 - val_recall: 0.5331 - val_auc: 0.9634 - val_prc: 0.8086
# Epoch 6/10
# 9250/9250 [==============================] - 1923s 208ms/step - loss: 0.9861 - accuracy: 0.6820 - precision: 0.8613 - recall: 0.5208 - auc: 0.9604 - prc: 0.7968 - val_loss: 0.9449 - val_accuracy: 0.6900 - val_precision: 0.8559 - val_recall: 0.5390 - val_auc: 0.9638 - val_prc: 0.8100
# Epoch 7/10
# 8771/9250 [===========================>..] - ETA: 1:27 - loss: 0.9745 - accuracy: 0.6843 - precision: 0.8614 - recall: 0.5248 - auc: 0.9613 - prc: 0.7998

# %%
tf.keras.utils.plot_model(model, show_shapes=True, rankdir="LR")

# %%
LATE_FUSION_RESULTS=MODELS_RESULTS
# %store LATE_FUSION_RESULTS

# %%
MODELS_RESULTS
# Out:
# {'LATE-FUSION-IMBALANCED': {'train': {'loss': 0.44294071197509766,
#    'accuracy': 0.8592727780342102,
#    'precision': 0.935438334941864,
#    'recall': 0.8145904541015625,
#    'auc': 0.9929890036582947,
#    'prc': 0.9546872973442078},
#   'validation': {'loss': 0.5120823383331299,
#    'accuracy': 0.8392542600631714,
#    'precision': 0.9149129986763,
#    'recall': 0.7920689582824707,
#    'auc': 0.9894083738327026,
#    'prc': 0.938427209854126},
#   'test': {'loss': 0.7310816049575806,
#    'accuracy': 0.7709833979606628,
#    'precision': 0.8604015707969666,
#    'recall': 0.6950399279594421,
#    'auc': 0.9763052463531494,
#    'prc': 0.8822578191757202}}}
